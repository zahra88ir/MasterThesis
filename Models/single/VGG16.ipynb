# %%
#import libraries
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, precision_score, recall_score, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping
from collections import Counter
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#class inputs
base_path = r"C:\Users\lenovo\USNThesis\CWRU"

image_directories = [
    base_path + "\\spectogtam\\bopolar7",
    base_path + "\\spectogtam\\bopolar14",
    base_path + "\\spectogtam\\bopolar21",
    base_path + "\\spectogtam\\irpolar7",
    base_path + "\\spectogtam\\irpolar14",
    base_path + "\\spectogtam\\irpolar21",
    base_path + "\\spectogtam\\orpolar7",
    base_path + "\\spectogtam\\orpolar14",
    base_path + "\\spectogtam\\orpolar21",
]

# %%
#class labeling
def get_label(directory):
    if "bopolar" in directory:
        return 0  
    elif "irpolar" in directory:
        return 1 
    else:
        return 2

# %%
pimages = []
plabels = []
for directory in image_directories:
    files = os.listdir(directory)
    for file in files:
        if file.endswith('.png'):
            file_path = os.path.join(directory, file)
            img = cv2.imread(file_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (64, 64))
            pimages.append(img)
            plabels.append(get_label(directory))

# %%
images = np.array(pimages)
labels = np.array(plabels)

# %%
# splitting
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
#Generating class weight
class_counts = Counter(labels)
total_samples = len(labels)
class_weights = {class_index: total_samples / (class_count * len(class_counts)) for class_index, class_count in class_counts.items()}

# %%
#generate data as a data augmentation step
datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
datagen.fit(X_train)

# %%
#define vgg16
base_model = VGG16(include_top=False, weights='imagenet', input_shape=(64, 64, 3))
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(3, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#model training
epochs_list = [20, 30]
batch_sizes = [32, 64]
results = []
best_accuracy = 0.0

for epoch in epochs_list:
    for batch_size in batch_sizes:
        print(f"Training with {epoch} epochs and {batch_size} batch size...")
    
        
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

        history = model.fit(X_train, y_train,
                            epochs=epoch,
                            batch_size=batch_size,
                            validation_split=0.2,
                            class_weight=class_weights)
        
        test_loss, test_accuracy = model.evaluate(X_test, y_test)
        predictions = model.predict(X_test)
        predicted_labels = np.argmax(predictions, axis=1)

        accuracy = accuracy_score(y_test, predicted_labels)
        f1 = f1_score(y_test, predicted_labels, average='weighted')
        precision_vals = precision_score(y_test, predicted_labels, average=None)
        recall_vals = recall_score(y_test, predicted_labels, average=None)

        n_classes = 3 
        fpr = dict()
        tpr = dict()
        roc_auc_vals = dict()

        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
            roc_auc_vals[i] = auc(fpr[i], tpr[i])

        results.append({
            'epochs': epoch,
            'batch_size': batch_size,
            'test_accuracy': test_accuracy,
            'accuracy': accuracy,
            'f1_score': f1,
            'precision': precision_vals,
            'recall': recall_vals,
            'roc_auc': roc_auc_vals
        })
# Out:
# Training with 20 epochs and 32 batch size...
# Epoch 1/20
# 36/36 [==============================] - 11s 293ms/step - loss: 5.0866 - accuracy: 0.5814 - val_loss: 0.4588 - val_accuracy: 0.7880
# Epoch 2/20
# 36/36 [==============================] - 10s 292ms/step - loss: 0.5367 - accuracy: 0.7770 - val_loss: 0.3584 - val_accuracy: 0.8198
# Epoch 3/20
# 36/36 [==============================] - 10s 277ms/step - loss: 0.4591 - accuracy: 0.8009 - val_loss: 0.3310 - val_accuracy: 0.8445
# Epoch 4/20
# 36/36 [==============================] - 10s 284ms/step - loss: 0.4156 - accuracy: 0.8195 - val_loss: 0.2426 - val_accuracy: 0.8940
# Epoch 5/20
# 36/36 [==============================] - 11s 299ms/step - loss: 0.3932 - accuracy: 0.8434 - val_loss: 0.2682 - val_accuracy: 0.9187
# Epoch 6/20
# 36/36 [==============================] - 11s 305ms/step - loss: 0.3710 - accuracy: 0.8398 - val_loss: 0.2477 - val_accuracy: 0.8481
# Epoch 7/20
# 36/36 [==============================] - 11s 295ms/step - loss: 0.3332 - accuracy: 0.8549 - val_loss: 0.2685 - val_accuracy: 0.8975
# Epoch 8/20
# 36/36 [==============================] - 10s 293ms/step - loss: 0.3582 - accuracy: 0.8460 - val_loss: 0.2267 - val_accuracy: 0.8763
# Epoch 9/20
# 36/36 [==============================] - 11s 297ms/step - loss: 0.3053 - accuracy: 0.8690 - val_loss: 0.2079 - val_accuracy: 0.9258
# Epoch 10/20
# 36/36 [==============================] - 11s 297ms/step - loss: 0.2955 - accuracy: 0.8673 - val_loss: 0.2223 - val_accuracy: 0.9011
# Epoch 11/20
# 36/36 [==============================] - 11s 293ms/step - loss: 0.2805 - accuracy: 0.8788 - val_loss: 0.1937 - val_accuracy: 0.8940
# Epoch 12/20
# 36/36 [==============================] - 11s 296ms/step - loss: 0.3090 - accuracy: 0.8602 - val_loss: 0.2515 - val_accuracy: 0.8728
# Epoch 13/20
# 36/36 [==============================] - 11s 298ms/step - loss: 0.2945 - accuracy: 0.8646 - val_loss: 0.1894 - val_accuracy: 0.9011
# Epoch 14/20
# 36/36 [==============================] - 11s 301ms/step - loss: 0.3175 - accuracy: 0.8628 - val_loss: 0.1970 - val_accuracy: 0.8869
# Epoch 15/20
# 36/36 [==============================] - 10s 292ms/step - loss: 0.2917 - accuracy: 0.8735 - val_loss: 0.2070 - val_accuracy: 0.9293
# Epoch 16/20
# 36/36 [==============================] - 11s 304ms/step - loss: 0.2947 - accuracy: 0.8637 - val_loss: 0.1589 - val_accuracy: 0.9364
# Epoch 17/20
# 36/36 [==============================] - 11s 296ms/step - loss: 0.2569 - accuracy: 0.8814 - val_loss: 0.1799 - val_accuracy: 0.8975
# Epoch 18/20
# 36/36 [==============================] - 11s 299ms/step - loss: 0.2554 - accuracy: 0.8894 - val_loss: 0.2164 - val_accuracy: 0.9505
# Epoch 19/20
# 36/36 [==============================] - 11s 311ms/step - loss: 0.2975 - accuracy: 0.8743 - val_loss: 0.1645 - val_accuracy: 0.9505
# Epoch 20/20
# 36/36 [==============================] - 11s 299ms/step - loss: 0.2583 - accuracy: 0.8885 - val_loss: 0.1543 - val_accuracy: 0.9647
# 12/12 [==============================] - 3s 218ms/step - loss: 0.1691 - accuracy: 0.9576
# 12/12 [==============================] - 3s 214ms/step
# Training with 20 epochs and 64 batch size...
# Epoch 1/20
# 18/18 [==============================] - 11s 611ms/step - loss: 0.3233 - accuracy: 0.8575 - val_loss: 0.1872 - val_accuracy: 0.8940
# Epoch 2/20
# 18/18 [==============================] - 11s 633ms/step - loss: 0.2556 - accuracy: 0.8903 - val_loss: 0.1591 - val_accuracy: 0.9541
# Epoch 3/20
# 18/18 [==============================] - 12s 651ms/step - loss: 0.2380 - accuracy: 0.8912 - val_loss: 0.1686 - val_accuracy: 0.9399
# Epoch 4/20
# 18/18 [==============================] - 12s 653ms/step - loss: 0.2511 - accuracy: 0.8903 - val_loss: 0.1539 - val_accuracy: 0.9329
# Epoch 5/20
# 18/18 [==============================] - 11s 614ms/step - loss: 0.2213 - accuracy: 0.8973 - val_loss: 0.1383 - val_accuracy: 0.9788
# Epoch 6/20
# 18/18 [==============================] - 10s 582ms/step - loss: 0.2243 - accuracy: 0.8991 - val_loss: 0.1400 - val_accuracy: 0.9329
# Epoch 7/20
# 18/18 [==============================] - 11s 611ms/step - loss: 0.2098 - accuracy: 0.9088 - val_loss: 0.1395 - val_accuracy: 0.9576
# Epoch 8/20
# 18/18 [==============================] - 10s 577ms/step - loss: 0.2095 - accuracy: 0.9097 - val_loss: 0.1271 - val_accuracy: 0.9647
# Epoch 9/20
# 18/18 [==============================] - 11s 603ms/step - loss: 0.2261 - accuracy: 0.8841 - val_loss: 0.1349 - val_accuracy: 0.9753
# Epoch 10/20
# 18/18 [==============================] - 11s 607ms/step - loss: 0.2277 - accuracy: 0.8929 - val_loss: 0.1375 - val_accuracy: 0.9647
# Epoch 11/20
# 18/18 [==============================] - 10s 570ms/step - loss: 0.2067 - accuracy: 0.9000 - val_loss: 0.1553 - val_accuracy: 0.9364
# Epoch 12/20
# 18/18 [==============================] - 11s 597ms/step - loss: 0.2003 - accuracy: 0.9088 - val_loss: 0.1417 - val_accuracy: 0.9647
# Epoch 13/20
# 18/18 [==============================] - 11s 593ms/step - loss: 0.2204 - accuracy: 0.8956 - val_loss: 0.1266 - val_accuracy: 0.9647
# Epoch 14/20
# 18/18 [==============================] - 10s 566ms/step - loss: 0.1991 - accuracy: 0.9000 - val_loss: 0.1228 - val_accuracy: 0.9647
# Epoch 15/20
# 18/18 [==============================] - 11s 597ms/step - loss: 0.1948 - accuracy: 0.9212 - val_loss: 0.1420 - val_accuracy: 0.9364
# Epoch 16/20
# 18/18 [==============================] - 11s 597ms/step - loss: 0.2317 - accuracy: 0.9062 - val_loss: 0.1152 - val_accuracy: 0.9717
# Epoch 17/20
# 18/18 [==============================] - 10s 565ms/step - loss: 0.2173 - accuracy: 0.9000 - val_loss: 0.1478 - val_accuracy: 0.9046
# Epoch 18/20
# 18/18 [==============================] - 11s 595ms/step - loss: 0.2315 - accuracy: 0.8894 - val_loss: 0.1383 - val_accuracy: 0.9576
# Epoch 19/20
# 18/18 [==============================] - 11s 601ms/step - loss: 0.2075 - accuracy: 0.9053 - val_loss: 0.1203 - val_accuracy: 0.9647
# Epoch 20/20
# 18/18 [==============================] - 11s 606ms/step - loss: 0.2108 - accuracy: 0.8982 - val_loss: 0.1154 - val_accuracy: 0.9859
# 12/12 [==============================] - 3s 265ms/step - loss: 0.1123 - accuracy: 0.9774
# 12/12 [==============================] - 3s 244ms/step
# Training with 30 epochs and 32 batch size...
# Epoch 1/30
# 36/36 [==============================] - 10s 290ms/step - loss: 0.2497 - accuracy: 0.8823 - val_loss: 0.1349 - val_accuracy: 0.9364
# Epoch 2/30
# 36/36 [==============================] - 11s 311ms/step - loss: 0.2671 - accuracy: 0.8858 - val_loss: 0.0969 - val_accuracy: 0.9859
# Epoch 3/30
# 36/36 [==============================] - 11s 308ms/step - loss: 0.2337 - accuracy: 0.8947 - val_loss: 0.1591 - val_accuracy: 0.9611
# Epoch 4/30
# 36/36 [==============================] - 11s 295ms/step - loss: 0.2222 - accuracy: 0.9106 - val_loss: 0.1341 - val_accuracy: 0.9541
# Epoch 5/30
# 36/36 [==============================] - 11s 300ms/step - loss: 0.2551 - accuracy: 0.8850 - val_loss: 0.1282 - val_accuracy: 0.9435
# Epoch 6/30
# 36/36 [==============================] - 11s 298ms/step - loss: 0.2765 - accuracy: 0.8752 - val_loss: 0.1152 - val_accuracy: 0.9788
# Epoch 7/30
# 36/36 [==============================] - 10s 290ms/step - loss: 0.2184 - accuracy: 0.8858 - val_loss: 0.1056 - val_accuracy: 0.9823
# Epoch 8/30
# 36/36 [==============================] - 11s 303ms/step - loss: 0.2371 - accuracy: 0.8805 - val_loss: 0.1295 - val_accuracy: 0.9576
# Epoch 9/30
# 36/36 [==============================] - 11s 305ms/step - loss: 0.2340 - accuracy: 0.8903 - val_loss: 0.1584 - val_accuracy: 0.9187
# Epoch 10/30
# 36/36 [==============================] - 10s 289ms/step - loss: 0.2614 - accuracy: 0.8681 - val_loss: 0.1691 - val_accuracy: 0.8940
# Epoch 11/30
# 36/36 [==============================] - 11s 316ms/step - loss: 0.2692 - accuracy: 0.8566 - val_loss: 0.1237 - val_accuracy: 0.9717
# Epoch 12/30
# 36/36 [==============================] - 12s 321ms/step - loss: 0.2655 - accuracy: 0.8726 - val_loss: 0.1458 - val_accuracy: 0.9117
# Epoch 13/30
# 36/36 [==============================] - 11s 300ms/step - loss: 0.2703 - accuracy: 0.8699 - val_loss: 0.1333 - val_accuracy: 0.9258
# Epoch 14/30
# 36/36 [==============================] - 11s 301ms/step - loss: 0.2164 - accuracy: 0.9000 - val_loss: 0.0795 - val_accuracy: 0.9823
# Epoch 15/30
# 36/36 [==============================] - 11s 305ms/step - loss: 0.2256 - accuracy: 0.8814 - val_loss: 0.1120 - val_accuracy: 0.9788
# Epoch 16/30
# 36/36 [==============================] - 11s 298ms/step - loss: 0.2736 - accuracy: 0.8655 - val_loss: 0.1184 - val_accuracy: 0.9682
# Epoch 17/30
# 36/36 [==============================] - 11s 293ms/step - loss: 0.2412 - accuracy: 0.8823 - val_loss: 0.1222 - val_accuracy: 0.9717
# Epoch 18/30
# 36/36 [==============================] - 11s 303ms/step - loss: 0.2212 - accuracy: 0.8947 - val_loss: 0.1211 - val_accuracy: 0.9541
# Epoch 19/30
# 36/36 [==============================] - 11s 296ms/step - loss: 0.2454 - accuracy: 0.8894 - val_loss: 0.1740 - val_accuracy: 0.8763
# Epoch 20/30
# 36/36 [==============================] - 11s 296ms/step - loss: 0.2508 - accuracy: 0.8832 - val_loss: 0.1236 - val_accuracy: 0.9576
# Epoch 21/30
# 36/36 [==============================] - 11s 303ms/step - loss: 0.2101 - accuracy: 0.8973 - val_loss: 0.0971 - val_accuracy: 0.9717
# Epoch 22/30
# 36/36 [==============================] - 11s 294ms/step - loss: 0.2476 - accuracy: 0.8973 - val_loss: 0.1373 - val_accuracy: 0.9682
# Epoch 23/30
# 36/36 [==============================] - 11s 301ms/step - loss: 0.2536 - accuracy: 0.8832 - val_loss: 0.1649 - val_accuracy: 0.9682
# Epoch 24/30
# 36/36 [==============================] - 11s 306ms/step - loss: 0.2274 - accuracy: 0.9009 - val_loss: 0.1236 - val_accuracy: 0.9258
# Epoch 25/30
# 36/36 [==============================] - 11s 305ms/step - loss: 0.2210 - accuracy: 0.8894 - val_loss: 0.1027 - val_accuracy: 0.9823
# Epoch 26/30
# 36/36 [==============================] - 10s 293ms/step - loss: 0.2272 - accuracy: 0.9018 - val_loss: 0.1093 - val_accuracy: 0.9753
# Epoch 27/30
# 36/36 [==============================] - 11s 305ms/step - loss: 0.2318 - accuracy: 0.8920 - val_loss: 0.0924 - val_accuracy: 0.9788
# Epoch 28/30
# 36/36 [==============================] - 11s 303ms/step - loss: 0.2349 - accuracy: 0.9027 - val_loss: 0.1301 - val_accuracy: 0.9682
# Epoch 29/30
# 36/36 [==============================] - 10s 292ms/step - loss: 0.2301 - accuracy: 0.8832 - val_loss: 0.0763 - val_accuracy: 0.9753
# Epoch 30/30
# 36/36 [==============================] - 11s 304ms/step - loss: 0.2107 - accuracy: 0.8947 - val_loss: 0.1251 - val_accuracy: 0.9505
# 12/12 [==============================] - 3s 213ms/step - loss: 0.1058 - accuracy: 0.9605
# 12/12 [==============================] - 3s 214ms/step
# Training with 30 epochs and 64 batch size...
# Epoch 1/30
# 18/18 [==============================] - 11s 594ms/step - loss: 0.2222 - accuracy: 0.8885 - val_loss: 0.0824 - val_accuracy: 0.9753
# Epoch 2/30
# 18/18 [==============================] - 10s 574ms/step - loss: 0.1991 - accuracy: 0.8956 - val_loss: 0.0851 - val_accuracy: 0.9859
# Epoch 3/30
# 18/18 [==============================] - 11s 604ms/step - loss: 0.1870 - accuracy: 0.9080 - val_loss: 0.1152 - val_accuracy: 0.9717
# Epoch 4/30
# 18/18 [==============================] - 11s 606ms/step - loss: 0.1709 - accuracy: 0.9221 - val_loss: 0.0723 - val_accuracy: 0.9823
# Epoch 5/30
# 18/18 [==============================] - 10s 578ms/step - loss: 0.1724 - accuracy: 0.9204 - val_loss: 0.0797 - val_accuracy: 0.9823
# Epoch 6/30
# 18/18 [==============================] - 10s 584ms/step - loss: 0.1875 - accuracy: 0.9124 - val_loss: 0.1061 - val_accuracy: 0.9682
# Epoch 7/30
# 18/18 [==============================] - 11s 599ms/step - loss: 0.1894 - accuracy: 0.9080 - val_loss: 0.0899 - val_accuracy: 0.9823
# Epoch 8/30
# 18/18 [==============================] - 10s 580ms/step - loss: 0.1784 - accuracy: 0.9168 - val_loss: 0.0851 - val_accuracy: 0.9859
# Epoch 9/30
# 18/18 [==============================] - 11s 595ms/step - loss: 0.1821 - accuracy: 0.9142 - val_loss: 0.0714 - val_accuracy: 0.9788
# Epoch 10/30
# 18/18 [==============================] - 11s 607ms/step - loss: 0.1866 - accuracy: 0.9195 - val_loss: 0.0821 - val_accuracy: 0.9788
# Epoch 11/30
# 18/18 [==============================] - 10s 586ms/step - loss: 0.1691 - accuracy: 0.9381 - val_loss: 0.0825 - val_accuracy: 0.9823
# Epoch 12/30
# 18/18 [==============================] - 10s 585ms/step - loss: 0.1627 - accuracy: 0.9301 - val_loss: 0.0849 - val_accuracy: 0.9788
# Epoch 13/30
# 18/18 [==============================] - 11s 594ms/step - loss: 0.1655 - accuracy: 0.9248 - val_loss: 0.0889 - val_accuracy: 0.9859
# Epoch 14/30
# 18/18 [==============================] - 10s 579ms/step - loss: 0.1502 - accuracy: 0.9257 - val_loss: 0.0800 - val_accuracy: 0.9823
# Epoch 15/30
# 18/18 [==============================] - 11s 598ms/step - loss: 0.1730 - accuracy: 0.9186 - val_loss: 0.0976 - val_accuracy: 0.9823
# Epoch 16/30
# 18/18 [==============================] - 11s 605ms/step - loss: 0.2003 - accuracy: 0.9097 - val_loss: 0.1133 - val_accuracy: 0.9753
# Epoch 17/30
# 18/18 [==============================] - 10s 578ms/step - loss: 0.1783 - accuracy: 0.9265 - val_loss: 0.0719 - val_accuracy: 0.9823
# Epoch 18/30
# 18/18 [==============================] - 11s 589ms/step - loss: 0.1618 - accuracy: 0.9168 - val_loss: 0.0661 - val_accuracy: 0.9788
# Epoch 19/30
# 18/18 [==============================] - 11s 595ms/step - loss: 0.1606 - accuracy: 0.9336 - val_loss: 0.0716 - val_accuracy: 0.9859
# Epoch 20/30
# 18/18 [==============================] - 10s 583ms/step - loss: 0.1753 - accuracy: 0.9239 - val_loss: 0.0667 - val_accuracy: 0.9788
# Epoch 21/30
# 18/18 [==============================] - 11s 602ms/step - loss: 0.1871 - accuracy: 0.9159 - val_loss: 0.0989 - val_accuracy: 0.9753
# Epoch 22/30
# 18/18 [==============================] - 11s 593ms/step - loss: 0.1786 - accuracy: 0.9159 - val_loss: 0.0839 - val_accuracy: 0.9788
# Epoch 23/30
# 18/18 [==============================] - 10s 580ms/step - loss: 0.1583 - accuracy: 0.9363 - val_loss: 0.0730 - val_accuracy: 0.9788
# Epoch 24/30
# 18/18 [==============================] - 11s 602ms/step - loss: 0.1584 - accuracy: 0.9301 - val_loss: 0.0639 - val_accuracy: 0.9823
# Epoch 25/30
# 18/18 [==============================] - 11s 600ms/step - loss: 0.1489 - accuracy: 0.9327 - val_loss: 0.0708 - val_accuracy: 0.9859
# Epoch 26/30
# 18/18 [==============================] - 10s 587ms/step - loss: 0.1466 - accuracy: 0.9257 - val_loss: 0.0894 - val_accuracy: 0.9788
# Epoch 27/30
# 18/18 [==============================] - 11s 595ms/step - loss: 0.1532 - accuracy: 0.9230 - val_loss: 0.0661 - val_accuracy: 0.9859
# Epoch 28/30
# 18/18 [==============================] - 11s 594ms/step - loss: 0.1850 - accuracy: 0.9186 - val_loss: 0.0761 - val_accuracy: 0.9859
# Epoch 29/30
# 18/18 [==============================] - 11s 591ms/step - loss: 0.1543 - accuracy: 0.9354 - val_loss: 0.0731 - val_accuracy: 0.9753
# Epoch 30/30
# 18/18 [==============================] - 11s 617ms/step - loss: 0.1543 - accuracy: 0.9283 - val_loss: 0.0846 - val_accuracy: 0.9788
# 12/12 [==============================] - 3s 222ms/step - loss: 0.1085 - accuracy: 0.9548
# 12/12 [==============================] - 3s 227ms/step

# %%
# print Validation, Accuracy, F1-Score
for result in results:
    print(f"Epochs: {result['epochs']}, Batch Size: {result['batch_size']},  Test Accuracy: {result['test_accuracy']}, F1-Score: {result['f1_score']}")
# Out:
# Epochs: 20, Batch Size: 32,  Test Accuracy: 0.9576271176338196, F1-Score: 0.9573780492138148
# Epochs: 20, Batch Size: 64,  Test Accuracy: 0.9774011373519897, F1-Score: 0.9773447441332674
# Epochs: 30, Batch Size: 32,  Test Accuracy: 0.9604519605636597, F1-Score: 0.9606956881744864
# Epochs: 30, Batch Size: 64,  Test Accuracy: 0.9548022747039795, F1-Score: 0.9552912450745856

# %%
#best results
best_result_test = max(results, key=lambda x: x['test_accuracy'])
print("\nBest Hyperparameters (Test Accuracy):")
print("Epochs:", best_result_test['epochs'])
print("Batch Size:", best_result_test['batch_size'])
print("Test Accuracy:", best_result_test['test_accuracy'])
# Out:
# Best Hyperparameters (Test Accuracy):
# Epochs: 20
# Batch Size: 64
# Test Accuracy: 0.9774011373519897

# %%
#plot roc curve
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = 3  

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend(loc="lower right")
plt.show()

# %%
precision = precision_score(y_test, predicted_labels, average=None)
recall = recall_score(y_test, predicted_labels, average=None)

print("\nPrecision for Each Class:", precision)
print("Recall for Each Class:", recall)
# Out:
# Precision for Each Class: [0.88811189 1.         1.        ]
# Recall for Each Class: [1.         0.94230769 0.91869919]

# %%
#plot conf_matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)
class_labels = ['bopolar', 'irpolar', 'orpolar']
confusion_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
