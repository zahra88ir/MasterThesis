# %%
#import libraries
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, precision_score, recall_score, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping
from collections import Counter
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#class inputs
base_path = r"C:\Users\lenovo\USNThesis\CWRU"

image_directories = [
    base_path + "\\spectogtam\\bopolar7",
    base_path + "\\spectogtam\\bopolar14",
    base_path + "\\spectogtam\\bopolar21",
    base_path + "\\spectogtam\\irpolar7",
    base_path + "\\spectogtam\\irpolar14",
    base_path + "\\spectogtam\\irpolar21",
    base_path + "\\spectogtam\\orpolar7",
    base_path + "\\spectogtam\\orpolar14",
    base_path + "\\spectogtam\\orpolar21",
]

# %%
#class labeling
def get_label(directory):
    if "bopolar" in directory:
        return 0  
    elif "irpolar" in directory:
        return 1 
    else:
        return 2

# %%
pimages = []
plabels = []
for directory in image_directories:
    files = os.listdir(directory)
    for file in files:
        if file.endswith('.png'):
            file_path = os.path.join(directory, file)
            img = cv2.imread(file_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (64, 64))
            pimages.append(img)
            plabels.append(get_label(directory))

# %%
images = np.array(pimages)
labels = np.array(plabels)

# %%
# splitting
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
#Generating class weight
class_counts = Counter(labels)
total_samples = len(labels)
class_weights = {class_index: total_samples / (class_count * len(class_counts)) for class_index, class_count in class_counts.items()}

# %%
#generate data as a data augmentation step
datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
datagen.fit(X_train)

# %%
#define resnet
base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(64, 64, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(3, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#model training
epochs_list = [20, 30]
batch_sizes = [32, 64]
results = []
best_accuracy = 0.0

for epoch in epochs_list:
    for batch_size in batch_sizes:
        print(f"Training with {epoch} epochs and {batch_size} batch size...")
    
        
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

        history = model.fit(X_train, y_train,
                            epochs=epoch,
                            batch_size=batch_size,
                            validation_split=0.2,
                            class_weight=class_weights)
        
        test_loss, test_accuracy = model.evaluate(X_test, y_test)
        predictions = model.predict(X_test)
        predicted_labels = np.argmax(predictions, axis=1)

        accuracy = accuracy_score(y_test, predicted_labels)
        f1 = f1_score(y_test, predicted_labels, average='weighted')
        precision_vals = precision_score(y_test, predicted_labels, average=None)
        recall_vals = recall_score(y_test, predicted_labels, average=None)

        n_classes = 3 
        fpr = dict()
        tpr = dict()
        roc_auc_vals = dict()

        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
            roc_auc_vals[i] = auc(fpr[i], tpr[i])

        results.append({
            'epochs': epoch,
            'batch_size': batch_size,
            'test_accuracy': test_accuracy,
            'accuracy': accuracy,
            'f1_score': f1,
            'precision': precision_vals,
            'recall': recall_vals,
            'roc_auc': roc_auc_vals
        })
# Out:
# Training with 20 epochs and 32 batch size...
# Epoch 1/20
# 36/36 [==============================] - 10s 193ms/step - loss: 1.0995 - accuracy: 0.5354 - val_loss: 0.7109 - val_accuracy: 0.7915
# Epoch 2/20
# 12/12 [==============================] - 2s 124ms/step - loss: 0.1757 - accuracy: 0.9266
# 12/12 [==============================] - 2s 127ms/step
# Training with 20 epochs and 64 batch size...
# Epoch 1/20
# 18/18 [==============================] - 5s 307ms/step - loss: 0.1577 - accuracy: 0.9381 - val_loss: 0.1219 - val_accuracy: 0.9505
# Epoch 2/20
# 18/18 [==============================] - 5s 291ms/step - loss: 0.1411 - accuracy: 0.9549 - val_loss: 0.1131 - val_accuracy: 0.9541
# Epoch 3/20
# 18/18 [==============================] - 5s 292ms/step - loss: 0.1272 - accuracy: 0.9602 - val_loss: 0.1207 - val_accuracy: 0.9470
# Epoch 4/20
# 18/18 [==============================] - 5s 304ms/step - loss: 0.1104 - accuracy: 0.9619 - val_loss: 0.1100 - val_accuracy: 0.9576
# Epoch 5/20
# 18/18 [==============================] - 5s 295ms/step - loss: 0.1130 - accuracy: 0.9628 - val_loss: 0.1124 - val_accuracy: 0.9647
# Epoch 6/20
# 18/18 [==============================] - 5s 292ms/step - loss: 0.1117 - accuracy: 0.9611 - val_loss: 0.1133 - val_accuracy: 0.9576
# Epoch 7/20
# 18/18 [==============================] - 5s 304ms/step - loss: 0.1075 - accuracy: 0.9646 - val_loss: 0.1101 - val_accuracy: 0.9505
# Epoch 8/20
# 18/18 [==============================] - 5s 297ms/step - loss: 0.1009 - accuracy: 0.9726 - val_loss: 0.1056 - val_accuracy: 0.9576
# Epoch 9/20
# 18/18 [==============================] - 5s 292ms/step - loss: 0.1049 - accuracy: 0.9708 - val_loss: 0.1096 - val_accuracy: 0.9682
# Epoch 10/20
# 18/18 [==============================] - 5s 306ms/step - loss: 0.0911 - accuracy: 0.9752 - val_loss: 0.1034 - val_accuracy: 0.9647
# Epoch 11/20
# 18/18 [==============================] - 5s 301ms/step - loss: 0.0944 - accuracy: 0.9708 - val_loss: 0.0996 - val_accuracy: 0.9541
# Epoch 12/20
# 18/18 [==============================] - 5s 293ms/step - loss: 0.1014 - accuracy: 0.9681 - val_loss: 0.1068 - val_accuracy: 0.9505
# Epoch 13/20
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0877 - accuracy: 0.9708 - val_loss: 0.1048 - val_accuracy: 0.9470
# Epoch 14/20
# 18/18 [==============================] - 6s 316ms/step - loss: 0.0902 - accuracy: 0.9743 - val_loss: 0.1030 - val_accuracy: 0.9505
# Epoch 15/20
# 18/18 [==============================] - 5s 304ms/step - loss: 0.0835 - accuracy: 0.9814 - val_loss: 0.0988 - val_accuracy: 0.9576
# Epoch 16/20
# 18/18 [==============================] - 6s 311ms/step - loss: 0.0988 - accuracy: 0.9673 - val_loss: 0.0980 - val_accuracy: 0.9576
# Epoch 17/20
# 18/18 [==============================] - 6s 331ms/step - loss: 0.0908 - accuracy: 0.9752 - val_loss: 0.0986 - val_accuracy: 0.9576
# Epoch 18/20
# 18/18 [==============================] - 6s 337ms/step - loss: 0.0770 - accuracy: 0.9779 - val_loss: 0.0962 - val_accuracy: 0.9541
# Epoch 19/20
# Epoch 5/30
# 18/18 [==============================] - 6s 329ms/step - loss: 0.0452 - accuracy: 0.9876 - val_loss: 0.0680 - val_accuracy: 0.9788
# Epoch 6/30
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0399 - accuracy: 0.9894 - val_loss: 0.0604 - val_accuracy: 0.9717
# Epoch 7/30
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0341 - accuracy: 0.9920 - val_loss: 0.0630 - val_accuracy: 0.9788
# Epoch 8/30
# 18/18 [==============================] - 5s 297ms/step - loss: 0.0367 - accuracy: 0.9885 - val_loss: 0.0638 - val_accuracy: 0.9753
# Epoch 9/30
# 18/18 [==============================] - 5s 302ms/step - loss: 0.0388 - accuracy: 0.9929 - val_loss: 0.0697 - val_accuracy: 0.9788
# Epoch 10/30
# 18/18 [==============================] - 5s 305ms/step - loss: 0.0318 - accuracy: 0.9920 - val_loss: 0.0693 - val_accuracy: 0.9753
# Epoch 11/30
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0342 - accuracy: 0.9929 - val_loss: 0.0621 - val_accuracy: 0.9717
# Epoch 12/30
# 18/18 [==============================] - 5s 307ms/step - loss: 0.0305 - accuracy: 0.9929 - val_loss: 0.0645 - val_accuracy: 0.9717
# Epoch 13/30
# 18/18 [==============================] - 6s 328ms/step - loss: 0.0331 - accuracy: 0.9965 - val_loss: 0.0690 - val_accuracy: 0.9717
# Epoch 14/30
# 18/18 [==============================] - 6s 311ms/step - loss: 0.0305 - accuracy: 0.9929 - val_loss: 0.0698 - val_accuracy: 0.9788
# Epoch 15/30
# 18/18 [==============================] - 6s 335ms/step - loss: 0.0274 - accuracy: 0.9965 - val_loss: 0.0653 - val_accuracy: 0.9753
# Epoch 16/30
# 18/18 [==============================] - 6s 337ms/step - loss: 0.0309 - accuracy: 0.9912 - val_loss: 0.0719 - val_accuracy: 0.9682
# Epoch 17/30
# 18/18 [==============================] - 6s 319ms/step - loss: 0.0397 - accuracy: 0.9894 - val_loss: 0.0719 - val_accuracy: 0.9717
# Epoch 18/30
# 18/18 [==============================] - 6s 323ms/step - loss: 0.0316 - accuracy: 0.9938 - val_loss: 0.0619 - val_accuracy: 0.9753
# Epoch 19/30
# 18/18 [==============================] - 6s 322ms/step - loss: 0.0312 - accuracy: 0.9938 - val_loss: 0.0603 - val_accuracy: 0.9788
# Epoch 20/30
# 18/18 [==============================] - 6s 317ms/step - loss: 0.0263 - accuracy: 0.9938 - val_loss: 0.0594 - val_accuracy: 0.9753
# Epoch 21/30
# 18/18 [==============================] - 6s 342ms/step - loss: 0.0293 - accuracy: 0.9938 - val_loss: 0.0598 - val_accuracy: 0.9717
# Epoch 22/30
# 18/18 [==============================] - 6s 323ms/step - loss: 0.0270 - accuracy: 0.9947 - val_loss: 0.0585 - val_accuracy: 0.9753
# Epoch 23/30
# 18/18 [==============================] - 6s 321ms/step - loss: 0.0249 - accuracy: 0.9956 - val_loss: 0.0656 - val_accuracy: 0.9717
# Epoch 24/30
# 18/18 [==============================] - 6s 334ms/step - loss: 0.0313 - accuracy: 0.9912 - val_loss: 0.0571 - val_accuracy: 0.9717
# Epoch 25/30
# 18/18 [==============================] - 6s 313ms/step - loss: 0.0252 - accuracy: 0.9956 - val_loss: 0.0572 - val_accuracy: 0.9717
# Epoch 26/30
# 18/18 [==============================] - 5s 304ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.0699 - val_accuracy: 0.9717
# Epoch 27/30
# 18/18 [==============================] - 6s 327ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.0605 - val_accuracy: 0.9717
# Epoch 28/30
# 18/18 [==============================] - 5s 297ms/step - loss: 0.0281 - accuracy: 0.9912 - val_loss: 0.0811 - val_accuracy: 0.9753
# Epoch 29/30
# 18/18 [==============================] - 5s 308ms/step - loss: 0.0291 - accuracy: 0.9929 - val_loss: 0.0646 - val_accuracy: 0.9717
# Epoch 30/30
# 18/18 [==============================] - 6s 318ms/step - loss: 0.0282 - accuracy: 0.9965 - val_loss: 0.0551 - val_accuracy: 0.9788
# 12/12 [==============================] - 1s 120ms/step - loss: 0.0719 - accuracy: 0.9774
# 12/12 [==============================] - 2s 123ms/step

# %%
# print Validation, Accuracy, F1-Score
for result in results:
    print(f"Epochs: {result['epochs']}, Batch Size: {result['batch_size']},  Test Accuracy: {result['test_accuracy']}, F1-Score: {result['f1_score']}")
# Out:
# Epochs: 20, Batch Size: 32,  Test Accuracy: 0.9265536665916443, F1-Score: 0.9262781386478122
# Epochs: 20, Batch Size: 64,  Test Accuracy: 0.9576271176338196, F1-Score: 0.9573608444741225
# Epochs: 30, Batch Size: 32,  Test Accuracy: 0.9802259802818298, F1-Score: 0.9801736536622264
# Epochs: 30, Batch Size: 64,  Test Accuracy: 0.9774011373519897, F1-Score: 0.9773603176814595

# %%
#best results
best_result_test = max(results, key=lambda x: x['test_accuracy'])
print("\nBest Hyperparameters (Test Accuracy):")
print("Epochs:", best_result_test['epochs'])
print("Batch Size:", best_result_test['batch_size'])
print("Test Accuracy:", best_result_test['test_accuracy'])
# Out:
# Best Hyperparameters (Test Accuracy):
# Epochs: 30
# Batch Size: 32
# Test Accuracy: 0.9802259802818298

# %%
#plot roc curve
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = 3  

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend(loc="lower right")
plt.show()

# %%
precision = precision_score(y_test, predicted_labels, average=None)
recall = recall_score(y_test, predicted_labels, average=None)

print("\nPrecision for Each Class:", precision)
print("Recall for Each Class:", recall)
# Out:
# Precision for Each Class: [0.976      0.98095238 0.97580645]
# Recall for Each Class: [0.96062992 0.99038462 0.98373984]

# %%
#plot conf_matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)
class_labels = ['bopolar', 'irpolar', 'orpolar']
confusion_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
