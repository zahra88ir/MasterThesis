# %%
#import libraries
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, precision_score, recall_score, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#class inputs
base_path = r"C:\Users\lenovo\USNThesis\CWRU"

image_directories = [
    base_path + "\\spectogtam\\bopolar7",
    base_path + "\\spectogtam\\bopolar14",
    base_path + "\\spectogtam\\bopolar21",
    base_path + "\\spectogtam\\irpolar7",
    base_path + "\\spectogtam\\irpolar14",
    base_path + "\\spectogtam\\irpolar21",
    base_path + "\\spectogtam\\orpolar7",
    base_path + "\\spectogtam\\orpolar14",
    base_path + "\\spectogtam\\orpolar21",
]

# %%
#class labeling
def get_label(directory):
    if "bopolar" in directory:
        return 0  
    elif "irpolar" in directory:
        return 1 
    else:
        return 2

# %%
pimages = []
plabels = []
for directory in image_directories:
    files = os.listdir(directory)
    for file in files:
        if file.endswith('.png'):
            file_path = os.path.join(directory, file)
            img = cv2.imread(file_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (64, 64))
            pimages.append(img)
            plabels.append(get_label(directory))

# %%
images = np.array(pimages)
labels = np.array(plabels)

# %%
# splitting
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
#Generating class weight

class_counts = Counter(labels)
total_samples = len(labels)
class_weights = {class_index: total_samples / (class_count * len(class_counts)) for class_index, class_count in class_counts.items()}

# %%
#generate data as a data augmentation step
datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
datagen.fit(X_train)

# %%
#define lenet
def LeNet(input_shape, num_classes):
    model = Sequential()
    model.add(Conv2D(6, (5, 5), padding="same", input_shape=input_shape, activation="relu"))
    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Conv2D(16, (5, 5), padding="valid", activation="relu"))
    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dense(120, activation="relu"))
    model.add(Dense(84, activation="relu"))
    model.add(Dense(num_classes, activation='softmax'))
    return model

model = LeNet((64, 64, 3), 3)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#model training
epochs_list = [20, 30]
batch_sizes = [32, 64]
results = []
best_accuracy = 0.0

for epoch in epochs_list:
    for batch_size in batch_sizes:
        print(f"Training with {epoch} epochs and {batch_size} batch size...")
    
        
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

        history = model.fit(X_train, y_train,
                            epochs=epoch,
                            batch_size=batch_size,
                            validation_split=0.2,
                            class_weight=class_weights)
        
        test_loss, test_accuracy = model.evaluate(X_test, y_test)
        predictions = model.predict(X_test)
        predicted_labels = np.argmax(predictions, axis=1)

        accuracy = accuracy_score(y_test, predicted_labels)
        f1 = f1_score(y_test, predicted_labels, average='weighted')
        precision_vals = precision_score(y_test, predicted_labels, average=None)
        recall_vals = recall_score(y_test, predicted_labels, average=None)

        n_classes = 3 
        fpr = dict()
        tpr = dict()
        roc_auc_vals = dict()

        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
            roc_auc_vals[i] = auc(fpr[i], tpr[i])

        results.append({
            'epochs': epoch,
            'batch_size': batch_size,
            'test_accuracy': test_accuracy,
            'accuracy': accuracy,
            'f1_score': f1,
            'precision': precision_vals,
            'recall': recall_vals,
            'roc_auc': roc_auc_vals
        })
# Out:
# Training with 20 epochs and 32 batch size...
# Epoch 1/20
# 36/36 [==============================] - 2s 35ms/step - loss: 4.4216 - accuracy: 0.4407 - val_loss: 0.9695 - val_accuracy: 0.6007
# Epoch 2/20
# 36/36 [==============================] - 1s 29ms/step - loss: 0.7787 - accuracy: 0.6735 - val_loss: 0.6853 - val_accuracy: 0.7244
# Epoch 3/20
# 36/36 [==============================] - 1s 33ms/step - loss: 0.6547 - accuracy: 0.7150 - val_loss: 0.5260 - val_accuracy: 0.7739
# Epoch 4/20
# 36/36 [==============================] - 1s 32ms/step - loss: 0.4345 - accuracy: 0.8221 - val_loss: 0.3547 - val_accuracy: 0.8516
# Epoch 5/20
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2937 - accuracy: 0.8982 - val_loss: 0.2229 - val_accuracy: 0.9152
# Epoch 6/20
# 36/36 [==============================] - 1s 32ms/step - loss: 0.1969 - accuracy: 0.9354 - val_loss: 0.1664 - val_accuracy: 0.9329
# Epoch 7/20
# 36/36 [==============================] - 1s 29ms/step - loss: 0.1009 - accuracy: 0.9779 - val_loss: 0.0668 - val_accuracy: 0.9929
# Epoch 8/20
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0464 - accuracy: 0.9938 - val_loss: 0.0393 - val_accuracy: 0.9965
# Epoch 9/20
# 36/36 [==============================] - 1s 30ms/step - loss: 0.0342 - accuracy: 0.9938 - val_loss: 0.0541 - val_accuracy: 0.9859
# Epoch 10/20
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0133 - accuracy: 0.9982 - val_loss: 0.0256 - val_accuracy: 0.9965
# Epoch 11/20
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9894
# Epoch 12/20
# 36/36 [==============================] - 1s 28ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 0.9965
# Epoch 13/20
# 36/36 [==============================] - 1s 32ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9859
# Epoch 14/20
# 36/36 [==============================] - 1s 35ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9929
# Epoch 15/20
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9929
# Epoch 16/20
# 36/36 [==============================] - 1s 41ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9965
# Epoch 17/20
# 36/36 [==============================] - 1s 36ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9929
# Epoch 18/20
# 36/36 [==============================] - 1s 33ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9929
# Epoch 19/20
# 36/36 [==============================] - 1s 35ms/step - loss: 8.2423e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9965
# Epoch 20/20
# 36/36 [==============================] - 1s 33ms/step - loss: 7.1608e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9965
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0088 - accuracy: 0.9972
# 12/12 [==============================] - 0s 8ms/step
# Training with 20 epochs and 64 batch size...
# Epoch 1/20
# 18/18 [==============================] - 1s 58ms/step - loss: 6.3980e-04 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 0.9929
# Epoch 2/20
# 18/18 [==============================] - 1s 56ms/step - loss: 5.7643e-04 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9965
# Epoch 3/20
# 18/18 [==============================] - 1s 57ms/step - loss: 5.5077e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9929
# Epoch 4/20
# 18/18 [==============================] - 1s 56ms/step - loss: 5.0569e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9929
# Epoch 5/20
# 18/18 [==============================] - 1s 56ms/step - loss: 4.8406e-04 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9929
# Epoch 6/20
# 18/18 [==============================] - 1s 56ms/step - loss: 4.6118e-04 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9929
# Epoch 7/20
# 18/18 [==============================] - 1s 55ms/step - loss: 4.4405e-04 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9929
# Epoch 8/20
# 18/18 [==============================] - 1s 55ms/step - loss: 4.2095e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9929
# Epoch 9/20
# 18/18 [==============================] - 1s 54ms/step - loss: 3.9717e-04 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9929
# Epoch 10/20
# 18/18 [==============================] - 1s 55ms/step - loss: 3.8201e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9965
# Epoch 11/20
# 18/18 [==============================] - 1s 55ms/step - loss: 3.8227e-04 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9929
# Epoch 12/20
# 18/18 [==============================] - 1s 52ms/step - loss: 3.4401e-04 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9929
# Epoch 13/20
# 18/18 [==============================] - 1s 54ms/step - loss: 3.3643e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9929
# Epoch 14/20
# 18/18 [==============================] - 1s 50ms/step - loss: 3.2639e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9929
# Epoch 15/20
# 18/18 [==============================] - 1s 51ms/step - loss: 3.2349e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9929
# Epoch 16/20
# 18/18 [==============================] - 1s 52ms/step - loss: 2.9201e-04 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9929
# Epoch 17/20
# 18/18 [==============================] - 1s 51ms/step - loss: 2.8167e-04 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9929
# Epoch 18/20
# 18/18 [==============================] - 1s 50ms/step - loss: 2.7094e-04 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9929
# Epoch 19/20
# 18/18 [==============================] - 1s 50ms/step - loss: 2.6185e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9929
# Epoch 20/20
# 18/18 [==============================] - 1s 51ms/step - loss: 2.5165e-04 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9929
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0108 - accuracy: 0.9972
# 12/12 [==============================] - 0s 8ms/step
# Training with 30 epochs and 32 batch size...
# Epoch 1/30
# 36/36 [==============================] - 1s 29ms/step - loss: 2.4985e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9929
# Epoch 2/30
# 36/36 [==============================] - 1s 29ms/step - loss: 2.3582e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9929
# Epoch 3/30
# 36/36 [==============================] - 1s 30ms/step - loss: 2.1142e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9929
# Epoch 4/30
# 36/36 [==============================] - 1s 31ms/step - loss: 2.1608e-04 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9929
# Epoch 5/30
# 36/36 [==============================] - 1s 32ms/step - loss: 1.9109e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9929
# Epoch 6/30
# 36/36 [==============================] - 1s 32ms/step - loss: 1.8002e-04 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9929
# Epoch 7/30
# 36/36 [==============================] - 1s 32ms/step - loss: 1.7290e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9929
# Epoch 8/30
# 36/36 [==============================] - 1s 35ms/step - loss: 1.5012e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9929
# Epoch 9/30
# 36/36 [==============================] - 1s 31ms/step - loss: 1.3903e-04 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9929
# Epoch 10/30
# 36/36 [==============================] - 1s 29ms/step - loss: 1.3417e-04 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9929
# Epoch 11/30
# 36/36 [==============================] - 1s 29ms/step - loss: 1.2228e-04 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9929
# Epoch 12/30
# 36/36 [==============================] - 1s 31ms/step - loss: 1.2854e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9929
# Epoch 13/30
# 36/36 [==============================] - 1s 32ms/step - loss: 1.1883e-04 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9929
# Epoch 14/30
# 36/36 [==============================] - 1s 32ms/step - loss: 1.0576e-04 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 0.9929
# Epoch 15/30
# 36/36 [==============================] - 1s 32ms/step - loss: 1.0259e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9929
# Epoch 16/30
# 36/36 [==============================] - 1s 32ms/step - loss: 9.4686e-05 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9929
# Epoch 17/30
# 36/36 [==============================] - 1s 34ms/step - loss: 9.1990e-05 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9929
# Epoch 18/30
# 36/36 [==============================] - 1s 30ms/step - loss: 8.5646e-05 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9929
# Epoch 19/30
# 36/36 [==============================] - 1s 32ms/step - loss: 8.4114e-05 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9929
# Epoch 20/30
# 36/36 [==============================] - 1s 34ms/step - loss: 7.7532e-05 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9929
# Epoch 21/30
# 36/36 [==============================] - 1s 33ms/step - loss: 7.5353e-05 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9929
# Epoch 22/30
# 36/36 [==============================] - 1s 30ms/step - loss: 7.4435e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9929
# Epoch 23/30
# 36/36 [==============================] - 1s 30ms/step - loss: 6.7040e-05 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9929
# Epoch 24/30
# 36/36 [==============================] - 1s 29ms/step - loss: 6.5036e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9929
# Epoch 25/30
# 36/36 [==============================] - 1s 29ms/step - loss: 6.2202e-05 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9929
# Epoch 26/30
# 36/36 [==============================] - 1s 29ms/step - loss: 5.9783e-05 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9929
# Epoch 27/30
# 36/36 [==============================] - 1s 29ms/step - loss: 5.9594e-05 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9929
# Epoch 28/30
# 36/36 [==============================] - 1s 32ms/step - loss: 5.7159e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9929
# Epoch 29/30
# 36/36 [==============================] - 1s 32ms/step - loss: 5.3468e-05 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9929
# Epoch 30/30
# 36/36 [==============================] - 1s 32ms/step - loss: 5.1193e-05 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9929
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0114 - accuracy: 0.9972
# 12/12 [==============================] - 0s 10ms/step
# Training with 30 epochs and 64 batch size...
# Epoch 1/30
# 18/18 [==============================] - 1s 59ms/step - loss: 4.8890e-05 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9929
# Epoch 2/30
# 18/18 [==============================] - 1s 57ms/step - loss: 4.8207e-05 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9929
# Epoch 3/30
# 18/18 [==============================] - 1s 56ms/step - loss: 4.7450e-05 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9929
# Epoch 4/30
# 18/18 [==============================] - 1s 56ms/step - loss: 4.5835e-05 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9929
# Epoch 5/30
# 18/18 [==============================] - 1s 54ms/step - loss: 4.5645e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9929
# Epoch 6/30
# 18/18 [==============================] - 1s 53ms/step - loss: 4.3631e-05 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9929
# Epoch 7/30
# 18/18 [==============================] - 1s 52ms/step - loss: 4.3532e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9929
# Epoch 8/30
# 18/18 [==============================] - 1s 53ms/step - loss: 4.2405e-05 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9929
# Epoch 9/30
# 18/18 [==============================] - 1s 50ms/step - loss: 4.1585e-05 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9929
# Epoch 10/30
# 18/18 [==============================] - 1s 49ms/step - loss: 4.0513e-05 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9929
# Epoch 11/30
# 18/18 [==============================] - 1s 52ms/step - loss: 4.0991e-05 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9929
# Epoch 12/30
# 18/18 [==============================] - 1s 54ms/step - loss: 3.9829e-05 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9929
# Epoch 13/30
# 18/18 [==============================] - 1s 54ms/step - loss: 3.8272e-05 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9929
# Epoch 14/30
# 18/18 [==============================] - 1s 53ms/step - loss: 3.8069e-05 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9929
# Epoch 15/30
# 18/18 [==============================] - 1s 54ms/step - loss: 3.7674e-05 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9929
# Epoch 16/30
# 18/18 [==============================] - 1s 53ms/step - loss: 3.6536e-05 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9929
# Epoch 17/30
# 18/18 [==============================] - 1s 55ms/step - loss: 3.5693e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9929
# Epoch 18/30
# 18/18 [==============================] - 1s 57ms/step - loss: 3.5144e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9929
# Epoch 19/30
# 18/18 [==============================] - 1s 52ms/step - loss: 3.4683e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9929
# Epoch 20/30
# 18/18 [==============================] - 1s 52ms/step - loss: 3.4535e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9929
# Epoch 21/30
# 18/18 [==============================] - 1s 52ms/step - loss: 3.3837e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9929
# Epoch 22/30
# 18/18 [==============================] - 1s 53ms/step - loss: 3.3207e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9929
# Epoch 23/30
# 18/18 [==============================] - 1s 51ms/step - loss: 3.2799e-05 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9929
# Epoch 24/30
# 18/18 [==============================] - 1s 54ms/step - loss: 3.2192e-05 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9929
# Epoch 25/30
# 18/18 [==============================] - 1s 50ms/step - loss: 3.1159e-05 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9929
# Epoch 26/30
# 18/18 [==============================] - 1s 49ms/step - loss: 3.0828e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9929
# Epoch 27/30
# 18/18 [==============================] - 1s 50ms/step - loss: 3.0398e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9929
# Epoch 28/30
# 18/18 [==============================] - 1s 51ms/step - loss: 2.9898e-05 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9929
# Epoch 29/30
# 18/18 [==============================] - 1s 54ms/step - loss: 2.9369e-05 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9929
# Epoch 30/30
# 18/18 [==============================] - 1s 53ms/step - loss: 2.8886e-05 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9929
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 0.9972
# 12/12 [==============================] - 0s 9ms/step

# %%
# print Validation, Accuracy, F1-Score
for result in results:
    print(f"Epochs: {result['epochs']}, Batch Size: {result['batch_size']},  Test Accuracy: {result['test_accuracy']}, F1-Score: {result['f1_score']}")
# Out:
# Epochs: 20, Batch Size: 32,  Test Accuracy: 0.9971751570701599, F1-Score: 0.9971752768556863
# Epochs: 20, Batch Size: 64,  Test Accuracy: 0.9971751570701599, F1-Score: 0.9971752768556863
# Epochs: 30, Batch Size: 32,  Test Accuracy: 0.9971751570701599, F1-Score: 0.9971752768556863
# Epochs: 30, Batch Size: 64,  Test Accuracy: 0.9971751570701599, F1-Score: 0.9971752768556863

# %%
#best results
best_result_test = max(results, key=lambda x: x['test_accuracy'])
print("\nBest Hyperparameters (Test Accuracy):")
print("Epochs:", best_result_test['epochs'])
print("Batch Size:", best_result_test['batch_size'])
print("Test Accuracy:", best_result_test['test_accuracy'])
# Out:
# Best Hyperparameters (Test Accuracy):
# Epochs: 20
# Batch Size: 32
# Test Accuracy: 0.9971751570701599

# %%
#plot roc curve
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = 3 

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])


plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend(loc="lower right")
plt.show()

# %%
precision = precision_score(y_test, predicted_labels, average=None)
recall = recall_score(y_test, predicted_labels, average=None)

print("\nPrecision for Each Class:", precision)
print("Recall for Each Class:", recall)
# Out:
# Precision for Each Class: [1.         1.         0.99193548]
# Recall for Each Class: [0.99212598 1.         1.        ]

# %%
#plot conf_matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)
class_labels = ['bopolar', 'irpolar', 'orpolar']
confusion_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
