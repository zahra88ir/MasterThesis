# %%
#import libraries
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc, precision_score, recall_score, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#class inputs
base_path = r"C:\Users\lenovo\USNThesis\CWRU"

image_directories = [
    base_path + "\\spectogtam\\bopolar7",
    base_path + "\\spectogtam\\bopolar14",
    base_path + "\\spectogtam\\bopolar21",
    base_path + "\\spectogtam\\irpolar7",
    base_path + "\\spectogtam\\irpolar14",
    base_path + "\\spectogtam\\irpolar21",
    base_path + "\\spectogtam\\orpolar7",
    base_path + "\\spectogtam\\orpolar14",
    base_path + "\\spectogtam\\orpolar21",
]

# %%
#class labeling
def get_label(directory):
    if "bopolar" in directory:
        return 0  
    elif "irpolar" in directory:
        return 1 
    else:
        return 2

# %%
pimages = []
plabels = []
for directory in image_directories:
    files = os.listdir(directory)
    for file in files:
        if file.endswith('.png'):
            file_path = os.path.join(directory, file)
            img = cv2.imread(file_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (224, 224))
            pimages.append(img)
            plabels.append(get_label(directory))

# %%
images = np.array(pimages)
labels = np.array(plabels)

# %%
# splitting
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
#Generating class weight
class_counts = Counter(labels)
total_samples = len(labels)
class_weights = {class_index: total_samples / (class_count * len(class_counts)) for class_index, class_count in class_counts.items()}

# %%
#generate data as a data augmentation step
datagen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
datagen.fit(X_train)

# %%
base_model = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(3, activation='softmax')(x) 
model = Model(inputs=base_model.input, outputs=output_layer)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#model training
epochs_list = [20, 30]
batch_sizes = [32, 64]
results = []
best_accuracy = 0.0

for epoch in epochs_list:
    for batch_size in batch_sizes:
        print(f"Training with {epoch} epochs and {batch_size} batch size...")
    
        
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

        history = model.fit(X_train, y_train,
                            epochs=epoch,
                            batch_size=batch_size,
                            validation_split=0.2,
                            class_weight=class_weights)
        
        test_loss, test_accuracy = model.evaluate(X_test, y_test)
        predictions = model.predict(X_test)
        predicted_labels = np.argmax(predictions, axis=1)

        accuracy = accuracy_score(y_test, predicted_labels)
        f1 = f1_score(y_test, predicted_labels, average='weighted')
        precision_vals = precision_score(y_test, predicted_labels, average=None)
        recall_vals = recall_score(y_test, predicted_labels, average=None)

        n_classes = 3 
        fpr = dict()
        tpr = dict()
        roc_auc_vals = dict()

        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
            roc_auc_vals[i] = auc(fpr[i], tpr[i])

        results.append({
            'epochs': epoch,
            'batch_size': batch_size,
            'test_accuracy': test_accuracy,
            'accuracy': accuracy,
            'f1_score': f1,
            'precision': precision_vals,
            'recall': recall_vals,
            'roc_auc': roc_auc_vals
        })
# Out:
# Training with 20 epochs and 32 batch size...
# Epoch 1/20
# 36/36 [==============================] - 34s 830ms/step - loss: 0.8245 - accuracy: 0.6363 - val_loss: 0.5722 - val_accuracy: 0.7562
# Epoch 2/20
# 12/12 [==============================] - 8s 620ms/step - loss: 0.1553 - accuracy: 0.9407
# 12/12 [==============================] - 9s 633ms/step
# Training with 20 epochs and 64 batch size...
# Epoch 1/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.2262 - accuracy: 0.9027 - val_loss: 0.1944 - val_accuracy: 0.9081
# Epoch 2/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.2001 - accuracy: 0.9212 - val_loss: 0.1659 - val_accuracy: 0.9435
# Epoch 3/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1991 - accuracy: 0.9159 - val_loss: 0.1643 - val_accuracy: 0.9435
# Epoch 4/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1973 - accuracy: 0.9274 - val_loss: 0.1609 - val_accuracy: 0.9505
# Epoch 5/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1860 - accuracy: 0.9389 - val_loss: 0.1492 - val_accuracy: 0.9576
# Epoch 6/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.2298 - accuracy: 0.9071 - val_loss: 0.1633 - val_accuracy: 0.9399
# Epoch 7/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1831 - accuracy: 0.9319 - val_loss: 0.1630 - val_accuracy: 0.9399
# Epoch 8/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1813 - accuracy: 0.9292 - val_loss: 0.1641 - val_accuracy: 0.9329
# Epoch 9/20
# 18/18 [==============================] - 33s 2s/step - loss: 0.1769 - accuracy: 0.9354 - val_loss: 0.1522 - val_accuracy: 0.9647
# Epoch 10/20
# 18/18 [==============================] - 32s 2s/step - loss: 0.1882 - accuracy: 0.9345 - val_loss: 0.1524 - val_accuracy: 0.9435
# Epoch 11/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1654 - accuracy: 0.9416 - val_loss: 0.1347 - val_accuracy: 0.9682
# Epoch 12/20
# 18/18 [==============================] - 29s 2s/step - loss: 0.1764 - accuracy: 0.9265 - val_loss: 0.1440 - val_accuracy: 0.9470
# Epoch 13/20
# 18/18 [==============================] - 29s 2s/step - loss: 0.1899 - accuracy: 0.9221 - val_loss: 0.1380 - val_accuracy: 0.9505
# Epoch 14/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1883 - accuracy: 0.9212 - val_loss: 0.1396 - val_accuracy: 0.9470
# Epoch 15/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1656 - accuracy: 0.9407 - val_loss: 0.1303 - val_accuracy: 0.9470
# Epoch 16/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1658 - accuracy: 0.9407 - val_loss: 0.1319 - val_accuracy: 0.9576
# Epoch 17/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1759 - accuracy: 0.9248 - val_loss: 0.1430 - val_accuracy: 0.9611
# Epoch 18/20
# 18/18 [==============================] - 30s 2s/step - loss: 0.1672 - accuracy: 0.9442 - val_loss: 0.1260 - val_accuracy: 0.9576
# Epoch 19/20
# Epoch 17/30
# 36/36 [==============================] - 31s 852ms/step - loss: 0.1311 - accuracy: 0.9460 - val_loss: 0.0840 - val_accuracy: 0.9682
# Epoch 18/30
# 36/36 [==============================] - 31s 855ms/step - loss: 0.1538 - accuracy: 0.9381 - val_loss: 0.0895 - val_accuracy: 0.9788
# Epoch 19/30
# 36/36 [==============================] - 31s 856ms/step - loss: 0.1377 - accuracy: 0.9478 - val_loss: 0.0903 - val_accuracy: 0.9682
# Epoch 20/30
# 36/36 [==============================] - 31s 877ms/step - loss: 0.1274 - accuracy: 0.9496 - val_loss: 0.0959 - val_accuracy: 0.9717
# Epoch 21/30
# 36/36 [==============================] - 32s 891ms/step - loss: 0.1455 - accuracy: 0.9398 - val_loss: 0.0950 - val_accuracy: 0.9753
# Epoch 22/30
# 36/36 [==============================] - 31s 852ms/step - loss: 0.1210 - accuracy: 0.9522 - val_loss: 0.0830 - val_accuracy: 0.9647
# Epoch 23/30
# 36/36 [==============================] - 30s 852ms/step - loss: 0.1463 - accuracy: 0.9442 - val_loss: 0.0883 - val_accuracy: 0.9753
# Epoch 24/30
# 36/36 [==============================] - 32s 890ms/step - loss: 0.1256 - accuracy: 0.9558 - val_loss: 0.1172 - val_accuracy: 0.9541
# Epoch 25/30
# 36/36 [==============================] - 31s 871ms/step - loss: 0.1342 - accuracy: 0.9425 - val_loss: 0.0902 - val_accuracy: 0.9788
# Epoch 26/30
# 36/36 [==============================] - 32s 899ms/step - loss: 0.1515 - accuracy: 0.9442 - val_loss: 0.0836 - val_accuracy: 0.9823
# Epoch 27/30
# 36/36 [==============================] - 32s 895ms/step - loss: 0.1483 - accuracy: 0.9442 - val_loss: 0.0825 - val_accuracy: 0.9788
# Epoch 28/30
# 36/36 [==============================] - 33s 919ms/step - loss: 0.1254 - accuracy: 0.9487 - val_loss: 0.1043 - val_accuracy: 0.9682
# Epoch 29/30
# 36/36 [==============================] - 31s 861ms/step - loss: 0.1341 - accuracy: 0.9496 - val_loss: 0.0936 - val_accuracy: 0.9823
# Epoch 30/30
# 36/36 [==============================] - 33s 913ms/step - loss: 0.1217 - accuracy: 0.9566 - val_loss: 0.0816 - val_accuracy: 0.9753
# 12/12 [==============================] - 8s 655ms/step - loss: 0.0713 - accuracy: 0.9774
# 12/12 [==============================] - 8s 673ms/step
# Training with 30 epochs and 64 batch size...
# Epoch 1/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.1533 - accuracy: 0.9354 - val_loss: 0.0923 - val_accuracy: 0.9753
# Epoch 2/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.1244 - accuracy: 0.9549 - val_loss: 0.0833 - val_accuracy: 0.9717
# Epoch 3/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.1269 - accuracy: 0.9575 - val_loss: 0.0918 - val_accuracy: 0.9823
# Epoch 4/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.1126 - accuracy: 0.9593 - val_loss: 0.0863 - val_accuracy: 0.9788
# Epoch 5/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.0912 - accuracy: 0.9735 - val_loss: 0.0694 - val_accuracy: 0.9717
# Epoch 6/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0975 - accuracy: 0.9602 - val_loss: 0.0712 - val_accuracy: 0.9788
# Epoch 7/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.0963 - accuracy: 0.9681 - val_loss: 0.0744 - val_accuracy: 0.9753
# Epoch 8/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0965 - accuracy: 0.9646 - val_loss: 0.0895 - val_accuracy: 0.9753
# Epoch 9/30
# 18/18 [==============================] - 32s 2s/step - loss: 0.0996 - accuracy: 0.9681 - val_loss: 0.0688 - val_accuracy: 0.9717
# Epoch 10/30
# 18/18 [==============================] - 33s 2s/step - loss: 0.0833 - accuracy: 0.9761 - val_loss: 0.0876 - val_accuracy: 0.9753
# Epoch 11/30
# 18/18 [==============================] - 32s 2s/step - loss: 0.0980 - accuracy: 0.9646 - val_loss: 0.0741 - val_accuracy: 0.9788
# Epoch 12/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.0940 - accuracy: 0.9611 - val_loss: 0.0737 - val_accuracy: 0.9823
# Epoch 13/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.0915 - accuracy: 0.9646 - val_loss: 0.0862 - val_accuracy: 0.9753
# Epoch 14/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0868 - accuracy: 0.9708 - val_loss: 0.0724 - val_accuracy: 0.9753
# Epoch 15/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.1100 - accuracy: 0.9619 - val_loss: 0.0642 - val_accuracy: 0.9859
# Epoch 16/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.1033 - accuracy: 0.9584 - val_loss: 0.0717 - val_accuracy: 0.9823
# Epoch 17/30
# 18/18 [==============================] - 32s 2s/step - loss: 0.0941 - accuracy: 0.9690 - val_loss: 0.0715 - val_accuracy: 0.9823
# Epoch 18/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.0900 - accuracy: 0.9664 - val_loss: 0.0838 - val_accuracy: 0.9682
# Epoch 19/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0989 - accuracy: 0.9566 - val_loss: 0.0723 - val_accuracy: 0.9753
# Epoch 20/30
# 18/18 [==============================] - 29s 2s/step - loss: 0.1063 - accuracy: 0.9611 - val_loss: 0.0619 - val_accuracy: 0.9788
# Epoch 21/30
# 18/18 [==============================] - 29s 2s/step - loss: 0.0916 - accuracy: 0.9708 - val_loss: 0.0639 - val_accuracy: 0.9753
# Epoch 22/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0938 - accuracy: 0.9602 - val_loss: 0.0664 - val_accuracy: 0.9859
# Epoch 23/30
# 18/18 [==============================] - 31s 2s/step - loss: 0.0898 - accuracy: 0.9681 - val_loss: 0.0674 - val_accuracy: 0.9823
# Epoch 24/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0803 - accuracy: 0.9752 - val_loss: 0.0552 - val_accuracy: 0.9859
# Epoch 25/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0898 - accuracy: 0.9655 - val_loss: 0.0621 - val_accuracy: 0.9894
# Epoch 26/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0937 - accuracy: 0.9655 - val_loss: 0.0591 - val_accuracy: 0.9823
# Epoch 27/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.1003 - accuracy: 0.9681 - val_loss: 0.0678 - val_accuracy: 0.9717
# Epoch 28/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.1001 - accuracy: 0.9681 - val_loss: 0.0586 - val_accuracy: 0.9823
# Epoch 29/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.0943 - accuracy: 0.9628 - val_loss: 0.0648 - val_accuracy: 0.9823
# Epoch 30/30
# 18/18 [==============================] - 30s 2s/step - loss: 0.1027 - accuracy: 0.9611 - val_loss: 0.0824 - val_accuracy: 0.9823
# 12/12 [==============================] - 8s 633ms/step - loss: 0.0591 - accuracy: 0.9859
# 12/12 [==============================] - 8s 618ms/step

# %%
# print Validation, Accuracy, F1-Score
for result in results:
    print(f"Epochs: {result['epochs']}, Batch Size: {result['batch_size']},  Test Accuracy: {result['test_accuracy']}, F1-Score: {result['f1_score']}")
# Out:
# Epochs: 20, Batch Size: 32,  Test Accuracy: 0.9406779408454895, F1-Score: 0.9406693651382262
# Epochs: 20, Batch Size: 64,  Test Accuracy: 0.9548022747039795, F1-Score: 0.9553143995787036
# Epochs: 30, Batch Size: 32,  Test Accuracy: 0.9774011373519897, F1-Score: 0.9774196192948866
# Epochs: 30, Batch Size: 64,  Test Accuracy: 0.9858757257461548, F1-Score: 0.9859323030844066

# %%
#best results
best_result_test = max(results, key=lambda x: x['test_accuracy'])
print("\nBest Hyperparameters (Test Accuracy):")
print("Epochs:", best_result_test['epochs'])
print("Batch Size:", best_result_test['batch_size'])
print("Test Accuracy:", best_result_test['test_accuracy'])
# Out:
# Best Hyperparameters (Test Accuracy):
# Epochs: 30
# Batch Size: 64
# Test Accuracy: 0.9858757257461548

# %%
#plot roc curve
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = 3  

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test, predictions[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend(loc="lower right")
plt.show()

# %%
precision = precision_score(y_test, predicted_labels, average=None)
recall = recall_score(y_test, predicted_labels, average=None)

print("\nPrecision for Each Class:", precision)
print("Recall for Each Class:", recall)
# Out:
# Precision for Each Class: [0.96212121 1.         1.        ]
# Recall for Each Class: [1.         0.98076923 0.97560976]

# %%
#plot conf_matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)
class_labels = ['bopolar', 'irpolar', 'orpolar']
confusion_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_df, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
